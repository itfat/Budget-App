# %%
X_full = pd.read_excel('updated_responses.xlsx', index_col=False)

# %%
X_full.index
# Out:
# RangeIndex(start=0, stop=43, step=1)

# %%
X_full.head()
# Out:
#    What is your monthly income at namal(pocket-money, work-study or any other)?  \
# 0                                              10000
# 1                                               7000
# 2                                              15000
# 3                                              15000
# 4                                              10000
#
#   Your Gender City where you live  # times you travel home per semester  \
# 0      Female          Faisalabad                                     1
# 1        Male           Islamabad                                     0
# 2      Female             Karachi                                     0
# 3        Male           Faislabad                                     1
# 4      Female           Faislabad                                     0
#
#    # times you travel mianwali per month Things you buy [items]  \
# 0                                      0                    NaN
# 1                                      4                grocery
# 2                                      2       dresses, grocery
# 3                                     10       dresses, grocery
# 4                                      0                    NaN
#
#    Monthly mess food expenses  Traveling home expenses per semester  \
# 0                        7000                                  2000
# 1                        6000                                     0
# 2                        7000                                  3000
# 3                        8000                                  1500
# 4                        7000                                     0
#
#    Monthly Shopping Expenses  Monthly travel Mianwali expenses  \
# 0                          0                                 0
# 1                       1000                                 0
# 2                       5000                                 0
# 3                       2000                              2000
# 4                          0                                 0
#
#    Monthly savings  Other expenses  Outdoor dining and travel expenses
# 0                0            1000                                   0
# 1                0               0                                   0
# 2                0               0                                   0
# 3                0             500                                1000
# 4              500            2500                                   0

# %%
X_full.shape
# Out:
# (43, 13)

# %%
missing_val_by_col = (X_full.isnull().sum())

# %%
print(missing_val_by_col[missing_val_by_col>0])
# Out:
# Things you buy [items]    10
# dtype: int64

# %%
cols = X_full.columns[X_full.isnull().any()]

# %%
cols
# Out:
# Index(['Things you buy [items]'], dtype='object')

# %%
# reduced_X = (X_full.drop(['last_review','reviews_per_month'], axis=1))

# %%
reduced_X = X_full

# %%
reduced_X.head()
# Out:
#    What is your monthly income at namal(pocket-money, work-study or any other)?  \
# 0                                              10000
# 1                                               7000
# 2                                              15000
# 3                                              15000
# 4                                              10000
#
#   Your Gender City where you live  # times you travel home per semester  \
# 0      Female          Faisalabad                                     1
# 1        Male           Islamabad                                     0
# 2      Female             Karachi                                     0
# 3        Male           Faislabad                                     1
# 4      Female           Faislabad                                     0
#
#    # times you travel mianwali per month Things you buy [items]  \
# 0                                      0                    NaN
# 1                                      4                grocery
# 2                                      2       dresses, grocery
# 3                                     10       dresses, grocery
# 4                                      0                    NaN
#
#    Monthly mess food expenses  Traveling home expenses per semester  \
# 0                        7000                                  2000
# 1                        6000                                     0
# 2                        7000                                  3000
# 3                        8000                                  1500
# 4                        7000                                     0
#
#    Monthly Shopping Expenses  Monthly travel Mianwali expenses  \
# 0                          0                                 0
# 1                       1000                                 0
# 2                       5000                                 0
# 3                       2000                              2000
# 4                          0                                 0
#
#    Monthly savings  Other expenses  Outdoor dining and travel expenses
# 0                0            1000                                   0
# 1                0               0                                   0
# 2                0               0                                   0
# 3                0             500                                1000
# 4              500            2500                                   0

# %%
# reduced_X = reduced_X.fillna(0)

# %%
reduced_X.shape
# Out:
# (43, 13)

# %%
missing_val_by_col = (reduced_X.isnull().sum())

# %%
missing_val_by_col
# Out:
# What is your monthly income at namal(pocket-money, work-study or any other)?     0
# Your Gender                                                                      0
# City where you live                                                              0
# # times you travel home per semester                                             0
# # times you travel mianwali per month                                            0
# Things you buy [items]                                                          10
# Monthly mess food expenses                                                       0
# Traveling home expenses per semester                                             0
# Monthly Shopping Expenses                                                        0
# Monthly travel Mianwali expenses                                                 0
# Monthly savings                                                                  0
# Other expenses                                                                   0
# Outdoor dining and travel expenses                                               0
# dtype: int64

# %%
X = reduced_X.iloc[:,:-7]

# %%
X
# Out:
#     What is your monthly income at namal(pocket-money, work-study or any other)?  \
# 0                                               10000
# 1                                                7000
# 2                                               15000
# 3                                               15000
# 4                                               10000
# 5                                                8000
# 6                                               25000
# 7                                                5000
# 8                                                9000
# 9                                                5000
# 10                                              15000
# 11                                              25000
# 12                                              12000
# 13                                              15000
# 14                                              10000
# 15                                              13000
# 16                                               7000
# 17                                               4000
# 18                                              12000
# 19                                              14000
# 20                                              11000
# 21                                              10000
# 22                                              19000
# 23                                              15000
# 24                                              12000
# 25                                              13000
# 26                                              15000
# 27                                              13000
# 28                                              10000
# 29                                               8000
# 30                                              14000
# 31                                              18000
# 32                                              10000
# 33                                              16000
# 34                                              10000
# 35                                              12000
# 36                                              10000
# 37                                              13000
# 38                                              19000
# 39                                              14000
# 40                                               9000
# 41                                              18000
# 42                                               5000
#
#    Your Gender City where you live  # times you travel home per semester  \
# 0       Female          Faisalabad                                     1
# 1         Male           Islamabad                                     0
# 2       Female             Karachi                                     0
# 3         Male           Faislabad                                     1
# 4       Female           Faislabad                                     0
# 5         Male               Atock                                     0
# 6         Male           Islamabad                                     2
# 7       Female            Mainwali                                     5
# 8         Male          Rawalpindi                                     1
# 9         Male            Mianwali                                     1
# 10      Female          Faisalabad                                     1
# 11        Male              Lahore                                     2
# 12        Male          Faisalabad                                     1
# 13      Female              Multan                                     1
# 14      Female            Khanewal                                     2
# 15        Male              Multan                                     1
# 16        Male     Dera Ghazi Khan                                     1
# 17        Male              Kāmoke                                     0
# 18      Female            Peshawar                                     1
# 19        Male          Gujranwala                                     1
# 20        Male              Lahore                                     2
# 21      Female           Pakpattan                                     1
# 22      Female              Quetta                                     1
# 23      Female             Karachi                                     1
# 24        Male              Multan                                     1
# 25        Male            Peshawar                                     1
# 26      Female           Hyderabad                                     2
# 27      Female              Quetta                                     1
# 28        Male          Rawalpindi                                     2
# 29        Male             Karachi                                     1
# 30        Male          Faisalabad                                     2
# 31      Female          Faisalabad                                     2
# 32      Female          Faisalabad                                     1
# 33        Male           Islamabad                                     2
# 34      Female              Lahore                                     1
# 35        Male          Faisalabad                                     2
# 36      Female          Faisalabad                                     1
# 37        Male          Gujranwala                                     1
# 38        Male          Gujranwala                                     1
# 39      Female             Karachi                                     1
# 40      Female              Lahore                                     2
# 41        Male             Karachi                                     1
# 42      Female             Chiniot                                     1
#
#     # times you travel mianwali per month         Things you buy [items]
# 0                                       0                            NaN
# 1                                       4                        grocery
# 2                                       2               dresses, grocery
# 3                                      10               dresses, grocery
# 4                                       0                            NaN
# 5                                       4                            NaN
# 6                                      10  dresses, grocery, electronics
# 7                                       0                        grocery
# 8                                       4                          other
# 9                                       0                            NaN
# 10                                      0                 other, grocery
# 11                                      5                        dresses
# 12                                      2                            NaN
# 13                                      1                            NaN
# 14                                      1                            NaN
# 15                                      2                            NaN
# 16                                      0                            NaN
# 17                                      0                            NaN
# 18                                      1                        grocery
# 19                                      4                          other
# 20                                      0                          other
# 21                                      1        dresses, other, grocery
# 22                                      3        dresses, other, grocery
# 23                                      1                        dresses
# 24                                      2                          other
# 25                                      1                    electronics
# 26                                      2                          other
# 27                                      1                        grocery
# 28                                      2                          other
# 29                                      5                        dresses
# 30                                      1                    electronics
# 31                                      2                    electronics
# 32                                      1                          other
# 33                                      5                    electronics
# 34                                      0                          other
# 35                                      2                    electronics
# 36                                      0                          other
# 37                                      5                          other
# 38                                      9                        grocery
# 39                                      2                        grocery
# 40                                      3                        dresses
# 41                                      6                          other
# 42                                      0                        grocery

# %%
Y = reduced_X.iloc[:,6:]

# %%
Y
# Out:
#     Monthly mess food expenses  Traveling home expenses per semester  \
# 0                         7000                                  2000
# 1                         6000                                     0
# 2                         7000                                  3000
# 3                         8000                                  1500
# 4                         7000                                     0
# 5                         6500                                     0
# 6                         8000                                  4000
# 7                         2000                                  1000
# 8                         5000                                  1500
# 9                         4000                                   500
# 10                        5000                                  1500
# 11                       12000                                  3000
# 12                        8000                                   500
# 13                        6000                                  2000
# 14                        7000                                  3000
# 15                        6000                                  2000
# 16                        5000                                  1000
# 17                        4000                                     0
# 18                        7000                                  3000
# 19                        7000                                  1500
# 20                        1000                                  2000
# 21                        4000                                  2000
# 22                        7000                                  3000
# 23                        3000                                  3000
# 24                        2000                                  2000
# 25                        1500                                  1500
# 26                        4000                                  3000
# 27                        2000                                  1500
# 28                        5000                                  2000
# 29                        1500                                  2000
# 30                        1500                                  2000
# 31                        2000                                  2000
# 32                        3000                                  1000
# 33                        1500                                  3500
# 34                        3000                                  1000
# 35                        2000                                  2000
# 36                        3000                                  1000
# 37                        1000                                  2000
# 38                        1000                                  2000
# 39                        4000                                  3000
# 40                        3000                                   800
# 41                        3000                                  3000
# 42                        2000                                   800
#
#     Monthly Shopping Expenses  Monthly travel Mianwali expenses  \
# 0                           0                                 0
# 1                        1000                                 0
# 2                        5000                                 0
# 3                        2000                              2000
# 4                           0                                 0
# 5                           0                              1500
# 6                        5000                              3000
# 7                        1500                                 0
# 8                        1000                              1000
# 9                           0                                 0
# 10                       1000                                 0
# 11                       6000                              4000
# 12                       1000                                60
# 13                        500                              1000
# 14                          0                                 0
# 15                          0                              1000
# 16                          0                                 0
# 17                          0                                 0
# 18                       1000                                 0
# 19                       1000                              1000
# 20                       1000                              1000
# 21                       4000                                 0
# 22                       9000                               500
# 23                       2000                              2500
# 24                       1300                              3000
# 25                       2000                              1500
# 26                       1500                              3000
# 27                       1500                               500
# 28                       1000                              1000
# 29                        800                              2000
# 30                       2000                              1500
# 31                       2000                              2000
# 32                       3000                              1000
# 33                       2000                              5000
# 34                        500                                 0
# 35                       2000                              1000
# 36                       2000                                 0
# 37                       2000                              5000
# 38                       2000                              6000
# 39                       1000                              2000
# 40                       1000                              2000
# 41                       2000                              4000
# 42                       1000                                 0
#
#     Monthly savings  Other expenses  Outdoor dining and travel expenses
# 0                 0            1000                                   0
# 1                 0               0                                   0
# 2                 0               0                                   0
# 3                 0             500                                1000
# 4               500            2500                                   0
# 5                 0               0                                   0
# 6                 0            2000                                3000
# 7               500               0                                   0
# 8                 0             500                                   0
# 9                 0             500                                   0
# 10             1000            5500                                   0
# 11                0               0                                   0
# 12                0             300                                   0
# 13              500               0                                4000
# 14                0               0                                   0
# 15              500             500                                3000
# 16                0               0                                1000
# 17                0               0                                   0
# 18             1000               0                                   0
# 19                0               0                                3500
# 20                0            1000                                5000
# 21                0               0                                   0
# 22                0             500                                1000
# 23             3000               0                                1500
# 24              500             200                                3000
# 25             2000             500                                4000
# 26              500               0                                3000
# 27             6500            1000                                1500
# 28                0               0                                1000
# 29              800              80                                3000
# 30             4800             700                                2000
# 31             7000            1000                                2000
# 32             1000               0                                1000
# 33             2000               0                                2000
# 34             4000             500                                1000
# 35             2000            1000                                2000
# 36             2000            1000                                1000
# 37              500             500                                2000
# 38             3000            2000                                3000
# 39             1200             800                                2000
# 40              400             200                                1500
# 41             2000            1000                                3000
# 42              150              50                                1000

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, shuffle= False)

# %%
X_train
# Out:
#     What is your monthly income at namal(pocket-money, work-study or any other)?  \
# 0                                               10000
# 1                                                7000
# 2                                               15000
# 3                                               15000
# 4                                               10000
# 5                                                8000
# 6                                               25000
# 7                                                5000
# 8                                                9000
# 9                                                5000
# 10                                              15000
# 11                                              25000
# 12                                              12000
# 13                                              15000
# 14                                              10000
# 15                                              13000
# 16                                               7000
# 17                                               4000
# 18                                              12000
# 19                                              14000
# 20                                              11000
# 21                                              10000
# 22                                              19000
# 23                                              15000
# 24                                              12000
# 25                                              13000
# 26                                              15000
# 27                                              13000
#
#    Your Gender City where you live  # times you travel home per semester  \
# 0       Female          Faisalabad                                     1
# 1         Male           Islamabad                                     0
# 2       Female             Karachi                                     0
# 3         Male           Faislabad                                     1
# 4       Female           Faislabad                                     0
# 5         Male               Atock                                     0
# 6         Male           Islamabad                                     2
# 7       Female            Mainwali                                     5
# 8         Male          Rawalpindi                                     1
# 9         Male            Mianwali                                     1
# 10      Female          Faisalabad                                     1
# 11        Male              Lahore                                     2
# 12        Male          Faisalabad                                     1
# 13      Female              Multan                                     1
# 14      Female            Khanewal                                     2
# 15        Male              Multan                                     1
# 16        Male     Dera Ghazi Khan                                     1
# 17        Male              Kāmoke                                     0
# 18      Female            Peshawar                                     1
# 19        Male          Gujranwala                                     1
# 20        Male              Lahore                                     2
# 21      Female           Pakpattan                                     1
# 22      Female              Quetta                                     1
# 23      Female             Karachi                                     1
# 24        Male              Multan                                     1
# 25        Male            Peshawar                                     1
# 26      Female           Hyderabad                                     2
# 27      Female              Quetta                                     1
#
#     # times you travel mianwali per month         Things you buy [items]
# 0                                       0                            NaN
# 1                                       4                        grocery
# 2                                       2               dresses, grocery
# 3                                      10               dresses, grocery
# 4                                       0                            NaN
# 5                                       4                            NaN
# 6                                      10  dresses, grocery, electronics
# 7                                       0                        grocery
# 8                                       4                          other
# 9                                       0                            NaN
# 10                                      0                 other, grocery
# 11                                      5                        dresses
# 12                                      2                            NaN
# 13                                      1                            NaN
# 14                                      1                            NaN
# 15                                      2                            NaN
# 16                                      0                            NaN
# 17                                      0                            NaN
# 18                                      1                        grocery
# 19                                      4                          other
# 20                                      0                          other
# 21                                      1        dresses, other, grocery
# 22                                      3        dresses, other, grocery
# 23                                      1                        dresses
# 24                                      2                          other
# 25                                      1                    electronics
# 26                                      2                          other
# 27                                      1                        grocery

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for column_name in X_train.columns:
    if X_train[column_name].dtype == object:
         X_train[column_name] = le.fit_transform(X_train[column_name])
    else:
        pass
# Out:
# /home/lechat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# get the model
def get_model(n_inputs, n_outputs):
    model = keras.Sequential()
    model.add(layers.Dense(60, input_dim=n_inputs, kernel_initializer='he_uniform', activation='relu'))
    model.add(layers.Dense(20, input_dim=n_inputs, kernel_initializer='he_uniform', activation='relu'))
    model.add(layers.Dense(n_outputs, kernel_initializer='he_uniform'))
    model.compile(loss='mae', optimizer='adam')
    return model

# %%
n_inputs, n_outputs = X_train.shape[1], Y_train.shape[1]

# %%
print(n_inputs, n_outputs)
# Out:
# 6 7

# %%
model = get_model(n_inputs, n_outputs)

# %%
model.fit(X_train, Y_train, verbose=0, epochs=100)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for column_name in X_test.columns:
    if X_test[column_name].dtype == object:
         X_test[column_name] = le.fit_transform(X_test[column_name])
    else:
        pass

# %%
from sklearn.model_selection import RepeatedKFold
# evaluate a model using repeated k-fold cross-validation
def evaluate_model(X, y):
	results = list()
	n_inputs, n_outputs = X.shape[1], y.shape[1]
	# define evaluation procedure
	cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
	# enumerate folds
	for train_ix, test_ix in cv.split(X):
		# prepare data
		X_train, X_test = X[train_ix], X[test_ix]
		y_train, y_test = y[train_ix], y[test_ix]
		# define model
		model = get_model(n_inputs, n_outputs)
		# fit model
		model.fit(X_train, y_train, verbose=0, epochs=100)
		# evaluate model on test set
		mae = model.evaluate(X_test, y_test, verbose=0)
		# store result
		print('>%.3f' % mae)
		results.append(mae)
	return results

# %%
# evaluate model
results = evaluate_model(X_test, Y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-e27e4ae2786d> in <module>
#       1 # evaluate model
# ----> 2 results = evaluate_model(X_test, Y_test)
#
# <ipython-input-97-6dd37ed97a16> in evaluate_model(X, y)
#       9         for train_ix, test_ix in cv.split(X):
#      10                 # prepare data
# ---> 11                 X_train, X_test = X[train_ix], X[test_ix]
#      12                 y_train, y_test = y[train_ix], y[test_ix]
#      13                 # define model
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Int64Index([0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14], dtype='int64')] are in the [columns]"

# %%
# summarize performance
print('MAE: %.3f (%.3f)' % (mean(results), std(results)))

# %%
yhat = model.predict(X_test)
print(yhat)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# [[ 3.3539365e+03  1.0846204e+03  9.9304980e+02  2.0793879e+01
#   -2.0132407e+03  4.7820811e+00  2.7552975e+02]
#  [ 2.6855562e+03  8.6852106e+02  7.9386176e+02  1.5783005e+01
#   -1.6111370e+03  3.1881187e+00  2.2098727e+02]
#  [ 4.6960342e+03  1.5203513e+03  1.3880599e+03  2.7480026e+01
#   -2.8174473e+03  4.1565776e+00  3.8844901e+02]
#  [ 6.0373032e+03  1.9550377e+03  1.7845358e+03  3.5237782e+01
#   -3.6222644e+03  5.0307508e+00  4.9994556e+02]
#  [ 3.3538804e+03  1.0858676e+03  9.9179095e+02  1.9746695e+01
#   -2.0125197e+03  3.3657291e+00  2.7733893e+02]
#  [ 5.3687861e+03  1.7375486e+03  1.5866199e+03  3.1120321e+01
#   -3.2208391e+03  5.0964727e+00  4.4346542e+02]
#  [ 3.3514055e+03  1.0850082e+03  9.9342981e+02  2.1466606e+01
#   -2.0126343e+03  4.5033956e+00  2.7646295e+02]
#  [ 4.0263774e+03  1.3031050e+03  1.1894719e+03  2.3124889e+01
#   -2.4151724e+03  3.5994945e+00  3.3268362e+02]
#  [ 3.3530933e+03  1.0857988e+03  9.9194470e+02  2.0032724e+01
#   -2.0123270e+03  3.3989952e+00  2.7739600e+02]
#  [ 4.3626836e+03  1.4119348e+03  1.2894387e+03  2.5159252e+01
#   -2.6173818e+03  4.4316311e+00  3.6030713e+02]
#  [ 6.3771133e+03  2.0642488e+03  1.8840502e+03  3.6249489e+01
#   -3.8254824e+03  5.7053609e+00  5.2734546e+02]
#  [ 4.6942358e+03  1.5200657e+03  1.3895410e+03  2.8700306e+01
#   -2.8178022e+03  5.0441012e+00  3.8813974e+02]
#  [ 3.0193438e+03  9.7648553e+02  8.9283575e+02  1.8099911e+01
#   -1.8115826e+03  3.5857863e+00  2.4840582e+02]
#  [ 6.0387412e+03  1.9548978e+03  1.7861112e+03  3.5762222e+01
#   -3.6238975e+03  6.2566881e+00  4.9905579e+02]
#  [ 1.6773444e+03  5.4279663e+02  4.9541037e+02  9.5278006e+00
#   -1.0060039e+03  1.6537591e+00  1.3849609e+02]]

# %%
print(Y_test)
# Out:
#     Monthly mess food expenses  Traveling home expenses per semester  \
# 28                        5000                                  2000
# 29                        1500                                  2000
# 30                        1500                                  2000
# 31                        2000                                  2000
# 32                        3000                                  1000
# 33                        1500                                  3500
# 34                        3000                                  1000
# 35                        2000                                  2000
# 36                        3000                                  1000
# 37                        1000                                  2000
# 38                        1000                                  2000
# 39                        4000                                  3000
# 40                        3000                                   800
# 41                        3000                                  3000
# 42                        2000                                   800
#
#     Monthly Shopping Expenses  Monthly travel Mianwali expenses  \
# 28                       1000                              1000
# 29                        800                              2000
# 30                       2000                              1500
# 31                       2000                              2000
# 32                       3000                              1000
# 33                       2000                              5000
# 34                        500                                 0
# 35                       2000                              1000
# 36                       2000                                 0
# 37                       2000                              5000
# 38                       2000                              6000
# 39                       1000                              2000
# 40                       1000                              2000
# 41                       2000                              4000
# 42                       1000                                 0
#
#     Monthly savings  Other expenses  Outdoor dining and travel expenses
# 28                0               0                                1000
# 29              800              80                                3000
# 30             4800             700                                2000
# 31             7000            1000                                2000
# 32             1000               0                                1000
# 33             2000               0                                2000
# 34             4000             500                                1000
# 35             2000            1000                                2000
# 36             2000            1000                                1000
# 37              500             500                                2000
# 38             3000            2000                                3000
# 39             1200             800                                2000
# 40              400             200                                1500
# 41             2000            1000                                3000
# 42              150              50                                1000

# %%
print(X_test)
# Out:
#     What is your monthly income at namal(pocket-money, work-study or any other)?  \
# 28                                              10000
# 29                                               8000
# 30                                              14000
# 31                                              18000
# 32                                              10000
# 33                                              16000
# 34                                              10000
# 35                                              12000
# 36                                              10000
# 37                                              13000
# 38                                              19000
# 39                                              14000
# 40                                               9000
# 41                                              18000
# 42                                               5000
#
#     Your Gender  City where you live  # times you travel home per semester  \
# 28            1                    6                                     2
# 29            1                    4                                     1
# 30            1                    1                                     2
# 31            0                    1                                     2
# 32            0                    1                                     1
# 33            1                    3                                     2
# 34            0                    5                                     1
# 35            1                    1                                     2
# 36            0                    1                                     1
# 37            1                    2                                     1
# 38            1                    2                                     1
# 39            0                    4                                     1
# 40            0                    5                                     2
# 41            1                    4                                     1
# 42            0                    0                                     1
#
#     # times you travel mianwali per month  Things you buy [items]
# 28                                      2                       3
# 29                                      5                       0
# 30                                      1                       1
# 31                                      2                       1
# 32                                      1                       3
# 33                                      5                       1
# 34                                      0                       3
# 35                                      2                       1
# 36                                      0                       3
# 37                                      5                       3
# 38                                      9                       2
# 39                                      2                       2
# 40                                      3                       0
# 41                                      6                       3
# 42                                      0                       2

# %%
classifier.score(X_test,Y_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# -4.119667046537635

# %%
print(len(classifier.estimators_))
print(classifier.estimators_[0].feature_importances_)
print(classifier.estimators_[1].feature_importances_)
# Out:
# 7
# [0.17206255 0.04786021 0.23386383 0.07435823 0.24979156 0.22206363]
# [0.470401   0.03100173 0.17222625 0.20807957 0.04109647 0.07719498]
